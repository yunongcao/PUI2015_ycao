# %% [markdown]
# # TIME SERIES ANALYSIS
#
# ### Goal: Find outliers, trends and periodicity in the MTA turnstile data
#
#
# ### DATA:
# MTA subway fares. It is a complete dataset of
# rides logged by card swipes for 600 Manhattan stations.
#
# The data was organized  by Sina Kashuk at CUSP. You can get it in the github repo as well as here: http://cosmo.nyu.edu/~fb55/UI_CUSP_2015/data/MTA_Fare.npy.
#
# It contains 23 different subway card types
# (e.g. monthly pass, daily pass, Act for Disability pass…) as follows:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from IPython.display import Image
Image(filename = "Ridetypes.png")

# %% [markdown]
# Each time series (per station, per ticket type) contains
# the number of swipes per week for 194 weeks
# from 05/21/2010 to 02/21/2014.
#
# The data are available to you as a python data cube here:
#
# you can load it as
#
# np.load(“MTA_Fare.npy") and
#
#
# you will end up with a python numpy array of
# shape (600,23,194)
#
# ##note that the missing values are inputted as -1
#
# if you want to do things like algebra (summing time series for example) you need to take care of that! if you replace the -1 entries with NaN remember to use functions that can deal with nans:
# np.nanmean
# np.nansum...

# %%
mta = np.load("MTA_Fare.npy").astype('float')
mta.shape
# Out:
# (600, 23, 194)

# %% [markdown]
# ## Task 1:
# ### Event detection: Identify the most prominent event. There is a very significant drop (>3-sigma) in all time series.
# ### Identify it and figure out what it is due to.

# %%
ridetype = np.array(['10t', '14d', '1d', '2t', '30d', '7d', 'ada', 'afas', 'exp','ez',
            'ff','mc','mr','month','rfm','rr','sen','spec','tcmc','t',
            'umlim','xbus','stud'])

# %%
mta[mta == -1] = np.nan
dates = pd.date_range('20100521', periods=194, freq='W')
#print dates
ax1 = plt.figure(figsize = (10,5))
for i in range (0, 600):
    for j in range (0, 23):
        plt.plot(dates, np.log10(mta[i][j]))
plt.xticks(rotation=45)
plt.xlabel("week since 05/21/2010", fontsize = 20)
plt.ylabel("swipes (log10)", fontsize = 20)
#after I create a date range (for example with pd.date_range())
#in a log plot to enhance the visibility along the y axis (np.log10(weightedrides[i]))
#all time series, each station each ride type, look like this (pretty ugly)

# %% [markdown]
# #### This plot is messy. Trying to sum the ride counts by station and plot it.

# %%
#as described in the instruction for some of the analysis 
#one can sum time series for all stations
mta_allsum_sta = np.nansum(mta, axis=0)
print (mta_allsum_sta.shape)
#or for all ride types
mta_allsum_ridetypes = np.nansum(mta, axis=1)
print (mta_allsum_ridetypes.shape)
# Out:
# (23, 194)
# (600, 194)

# %%
ax2 = plt.figure(figsize = (10,5))
for i in range(0, 23):
    plt.plot(dates, mta_allsum_sta[i])
plt.xticks(rotation=45)
plt.xlabel("week since 05/21/2010", fontsize = 20)
plt.ylabel("swipes (log10)", fontsize = 20)

# %% [markdown]
# #### Judgying by the plot above, it seems to be an unusual event happend around Oct/Nov 2012, probably due to Hurricane Sandy.
# #### Now, verifying my assumption:

# %%
stadf = pd.DataFrame(data = mta_allsum_sta).dropna().transpose()
stadf.columns = ridetype
stadf.index = dates
stadf.head()
# Out:
#                  10t     14d     1d      2t    30d       7d      ada   afas  \
# 2010-05-23  11494615  530524  47801  186551  46808  3697443  8551937  10063
# 2010-05-30  12526859  583533  51486  199229  64353  3981808  9486394  11847
# 2010-06-06  12766627  586194  51636  199668  56994  4033030  9476538  12277
# 2010-06-13  12653675  562602  52063  196389  37429  4032753  9450081  11221
# 2010-06-20  12809694  548858  51153  194883  35210  3925446  9294002  10515
#
#                exp      ez  ...    month     rfm     rr    sen  spec    tcmc  \
# 2010-05-23  333197  512032  ...   123134  790110  59809  28221     0  124693
# 2010-05-30  282755  578023  ...   151948  908068  69209  32333     0  121713
# 2010-06-06  302028  615537  ...   151538  914124  69574  32618     0  122181
# 2010-06-13  305513  606270  ...   147094  902549  68099  32404     0  122051
# 2010-06-20  335780  563446  ...   137888  855573  66377  31933   176  119776
#
#                 t  umlim  xbus  stud
# 2010-05-23  21060   6128   358     0
# 2010-05-30  21670   6120   474     0
# 2010-06-06  21433   6490   465     0
# 2010-06-13  21630   6590   484     0
# 2010-06-20  20297   6313   452     0
#
# [5 rows x 23 columns]

# %%
sumbytype = stadf.sum(axis = 1)
thresholds = [sumbytype.mean() + 3*sumbytype.std(), 
              sumbytype.mean() - 3*sumbytype.std()]
print sumbytype[(sumbytype < thresholds[1]) | (sumbytype > thresholds[0])]
# Out:
# 2012-10-21    5218686
# Freq: W-SUN, dtype: float64

# %% [markdown]
# ### It turns out the most prominent event did happen in the week of Oct. 21 2012. Therefore, it was due to the effect from Hurrican Sandy.
# ***
#
# ## Task 2:
# ### Some of the time series are stationary, some have a complex structure, some show a downward trend: Identify the **ridership types**  that have steadily increased in popularity,  and that have steadily decreased. by how much? (e.g what is the ratio of usage in the first 10 and last 10 weeks)

# %%
weeks = np.arange(194)
roll_mean = pd.rolling_mean(mta_allsum_sta, 10)
#roll_mean.shape
ax3 = plt.figure(figsize = (10,5))
for i in range(0, 23):
    plt.plot(weeks, roll_mean[i])
plt.xlabel("weeks", fontsize = 20)
plt.ylabel("rolling mean of swipes", fontsize = 20)
plt.title("smoothed counts by weeks", fontsize = 20)

# %%
rmeandf = pd.DataFrame(data = roll_mean).transpose()
rmeandf.columns = ridetype
rmeandf.index = weeks
#rmeandf.head()
ratiodf = (rmeandf.iloc[-1]/rmeandf.iloc[9])
print ratiodf
# Out:
# 10t           NaN
# 14d           NaN
# 1d            NaN
# 2t            NaN
# 30d           NaN
# 7d            NaN
# ada           NaN
# afas          NaN
# exp           NaN
# ez       1.011725
# ff       1.018928
# mc       1.009874
# mr       1.019749
# month    1.016387
# rfm      0.997938
# rr       0.883547
# sen      0.543268
# spec     0.556560
# tcmc     0.715337
# t        1.059850
# umlim    1.067792
# xbus     1.059914
# stud     1.380577
# dtype: float64

# %% [markdown]
# ### Type: spec, sen, rr, 7d, 14d, mc are stabely increasing in popularity.
# ### Type: month, rfm, unlim are stabely decreasing in popularity.
# ***

# %% [markdown]
# ## Task 3:
# ### Several stations show a prominent annual periodicity. Identify the 4 **stations** (indentify them by the index of their location in the data cube) that show the most prominent periodic trend on an annual period (52 weeks). (Can you figure out what the periodic peak in rides is due to?)

# %%
freqdf = pd.DataFrame(mta_allsum_ridetypes)

freq = np.abs(np.fft.rfft(freqdf))
fig = plt.figure(figsize=(10,5))
ax5 = fig.add_subplot(111)
sample_rate = 1
for i in range(600):
    plt.plot(np.fft.rfftfreq(194, 1.0), (f[i]), '-')

plt.xlabel("period (week)", fontsize=20)
plt.ylim([0, 3e6])
plt.axvline(1.0/52,lw=5, color='red', label='at 1/52 weeks',alpha=0.8)
plt.legend(loc='best')

# %%
findex = []

for i in range(0,600):
    s = sorted(freq[i])
    smax = s[96]
    findex.append(smax)

a = []
a = sorted(findex)[-4:]
print a

print "station:", findex.index(a[0]), findex.index(a[1]), findex.index(a[2]), findex.index(a[3])
# Out:
# [2446320.5879031457, 2931895.8769513383, 2950388.929214194, 2980160.6355953491]
# station: 56 150 194 0

# %%
fig=plt.figure(figsize=(10,10))
ax6 = fig.add_subplot(211)
ax6.plot(np.fft.rfftfreq(194, 1.0), (f[194]), '-', label='station 194')
#ax6.set_xticklabels([ "%.1f"%(1/a) for a in (ax.get_xticks())], fontsize=20)
#ax6.set_ylim([0, 3000000])
#plt.axvline(1.0/52,lw=5, color='red', label='at 1/52 weeks',alpha=0.5)
#ax6.set_xlabel('Frequency', fontsize=20)
#ax6.set_ylabel('Power', fontsize=20)
#pl.legend(loc='best')

ax7 = fig.add_subplot(212)
ax7.plot(mta_df2.loc[194], '-', label='station 194')
#ax.set_ylim([0, 250000])
#ax.set_xlim([0, 200])
#ax.set_xlabel('Weeks', fontsize=20)
#ax.set_ylabel('Rides', fontsize=20)
#pl.legend(loc='best')
